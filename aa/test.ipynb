# %%
import numpy as np
import pandas as pd
import time

# %%
#########################################################
#near_cell

# %%
###################################

# %%
def near_cell(picture_num, df_cotimes, cut_off = .1):
    """Computing the counts of near cell pairs
    according to the cutoff denoted by user
    
    Parameters
    ______________
    picture_num: the number of the first few pictures
    chosen from all the pictures
    cut_off: the threshold to choose near cell pairs
    df_cotimes: the dataframe generated by funtion coexistence(),
    storing times of coexistence of cell pairs
    
    Returns
    ______________
    df_near: a dataframe similar to df_cotimes,
    recording the counts of near cell pairs
    """  
    for file_num in range(picture_num):
        df_dis = pd.read_csv('./distance_rate/t%03d-dis.csv' % (file_num+1), sep=',', header=None)
        index = df_dis.iloc[:,2] > cut_off
        df_remove = df_dis[index].iloc[:,:-1]
        #drop redoundance
        for i in range(df_remove.shape[0]):
            df_remove.iloc[i,:] = list(df_remove.iloc[i,:].sort_values())
        df_remove = df_remove.drop_duplicates([0,1])
        #drop counts that is larger than cute_off from total coexistence times
        for j in range(df_remove.shape[0]):
            cellA = df_remove.iloc[j,0]
            cellB = df_remove.iloc[j,1]
            index = (df_cotimes.iloc[:,0] == cellA) & (df_cotimes.iloc[:,1] == cellB)
            recount = int(df_cotimes[index].iloc[0,2]) - 1
            df_cotimes[index] = [cellA, cellB, recount]
        print(file_num)
    df_near = df_cotimes
    return df_near

# %%
picture_num = 180
df_cotimes = coexistence(picture_num)

# %%
df_cotimes.columns = [0,1,2]

# %%
df_cotimes.iloc[:7,:]
# Out:
#      0    1   2
# 0   AB   P1   1
# 1  ABa  ABp  12
# 2  ABa   P1   2
# 3  ABp   P1   2
# 4  ABa  EMS  10
# 5  ABa   P2  10
# 6  ABp  EMS  10

# %%
df_cotimes = pd.read_csv('./cotimes.csv', sep=',', header=None);df_cotimes.iloc[:7,:]
# Out:
#      0    1   2
# 0   AB   P1   1
# 1  ABa  ABp  12
# 2  ABa   P1   2
# 3  ABp   P1   2
# 4  ABa  EMS  10
# 5  ABa   P2  10
# 6  ABp  EMS  10

# %%
def main():
#    for i in range(180):
#        #converting format
#        print('converting format: %.0f%%' % ((i+1)/180*100), end='\r')
#        os.system('python clean_data.py -f ./nuclei/t%03d-nuclei -d ./test' % (i+1))
#        #compute and output distance rate
#        data = pd.read_csv('./test/t%03d-nuclei.csv' % (i+1), sep=',', header=None)
#        dis_rate = distance(data)
#        dis_rate.to_csv('./distance_rate/t%03d-dis.csv' % (i+1), index=None, header=None) 
#   
    picture_num = 180
    df_cotimes = coexistence(picture_num)
    df_cotimes.to_csv('./cotimes.csv', index=None, header=None)
    
    df_cotimes.columns = [0,1,2]
    df_near = near_cell(picture_num=picture_num, df_cotimes=df_cotimes)
    
    #for each cell pair, computing (near times) / (total times)
    df_corate = df_comtimes.copy()
    df_corate.iloc[:,2] = list(df_near.iloc[:,2] / df_cotimes[:,2])
    df_corate.to_csv('./corate.csv', index=None, header=None)

if __name__ == '__main__':
    main()
# Out:
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-635-d5cff08b97e0> in <module>()
#      22
#      23 if __name__ == '__main__':
# ---> 24     main()
#
# <ipython-input-635-d5cff08b97e0> in main()
#      14
#      15     df_cotimes.columns = [0,1,2]
# ---> 16     df_near = near_cell(picture_num=picture_num, df_cotimes=df_cotimes)
#      17
#      18     #for each cell pair, computing (near times) / (total times)
#
# <ipython-input-634-1e3e5f2be0fd> in near_cell(picture_num, df_cotimes, cut_off)
#      30             index = (df_cotimes.iloc[:,0] == cellA) & (df_cotimes.iloc[:,1] == cellB)
#      31             recount = int(df_cotimes[index].iloc[0,2]) - 1
# ---> 32             df_cotimes[index] = [cellA, cellB, recount]
#      33         print(file_num)
#      34     df_near = df_cotimes
#
# E:\ZXJ\program\Anaconda\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2512
#    2513         if isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2514             self._setitem_array(key, value)
#    2515         elif isinstance(key, DataFrame):
#    2516             self._setitem_frame(key, value)
#
# E:\ZXJ\program\Anaconda\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    2532             indexer = key.nonzero()[0]
#    2533             self._check_setitem_copy()
# -> 2534             self.loc._setitem_with_indexer(indexer, value)
#    2535         else:
#    2536             if isinstance(value, DataFrame):
#
# E:\ZXJ\program\Anaconda\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     637             self.obj._consolidate_inplace()
#     638             self.obj._data = self.obj._data.setitem(indexer=indexer,
# --> 639                                                     value=value)
#     640             self.obj._maybe_update_cacher(clear=True)
#     641
#
# E:\ZXJ\program\Anaconda\lib\site-packages\pandas\core\internals.py in setitem(self, **kwargs)
#    3439
#    3440     def setitem(self, **kwargs):
# -> 3441         return self.apply('setitem', **kwargs)
#    3442
#    3443     def putmask(self, **kwargs):
#
# E:\ZXJ\program\Anaconda\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# E:\ZXJ\program\Anaconda\lib\site-packages\pandas\core\internals.py in setitem(self, indexer, value, mgr)
#     842                         indexer.dtype == np.bool_ and
#     843                         len(indexer[indexer]) == len(value)):
# --> 844                     raise ValueError("cannot set using a list-like indexer "
#     845                                      "with a different length than the value")
#     846
#
# ValueError: cannot set using a list-like indexer with a different length than the value

# %%
dd = pd.read_csv('./embryo1/001.csv', header=None)

# %%
dd
# Out:
#      0    1     2          3
# 0    X    Y     Z  cell_name
# 1  291  167  17.0         AB
# 2  359  257  17.0         P1
